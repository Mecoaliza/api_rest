# %%
import requests
import pandas as pd

# %%
r = requests.get('https://api.github.com/events')

# %%
r.json()
# Out:
# [{'id': '42351590933',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 812133030,
#    'name': 'betgg/lava',
#    'url': 'https://api.github.com/repos/betgg/lava'},
#   'payload': {'repository_id': 812133030,
#    'push_id': 20453577308,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '9de31de30648352759bfc9f354bf8917a2397d47',
#    'before': '12d88d46e8318f046fefd91e960b3087a10cc914',
#    'commits': [{'sha': '9de31de30648352759bfc9f354bf8917a2397d47',
#      'author': {'email': 'rxmxdhxni@gmail.com', 'name': 'dante4rt'},
#      'message': '🛠️ Fix Ethereum network',
#      'distinct': True,
# ...

# %%
version = requests.get('https://api.github.com/versions')
version.json()
